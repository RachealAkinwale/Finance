# %% [markdown]
# Section A: Demographic Data
# Variable	Category	Frequency	Percentage
# age_group	21-30	45	56.25%
# 31-40	20	25.00%
# 41-50	10	12.50%
# 51-60	5	6.25%
# Total	80	100%
# marital_status	Single	50	62.50%
# Married	25	31.25%
# Divorced	3	3.75%
# Widow	2	2.50%
# Total	80	100%
# education_level	Diploma	40	50.00%
# B.Sc	30	37.50%
# Masters	8	10.00%
# PhD	2	2.50%
# Total	80	100%
# religion	Christian	65	81.25%
# Muslim	15	18.75%
# Total	80	100%
# Section B: Knowledge of Cervical Cancer Screening
# Variable	Category	Frequency	Percentage
# cervical_cancer_definition_correct	Yes	70	87.50%
# No	10	12.50%
# Total	80	100%
# screening_requires_surgery	Yes	20	25.00%
# No	50	62.50%
# Maybe	10	12.50%
# Total	80	100%
# 3is_cervical_cancer_screening_typically_done_by_taking_a_sample_from_the_cervix_and_analyzing_it	Yes	60	75.00%
# No	15	18.75%
# Maybe	5	6.25%
# Total	80	100%
# screening_preventive_purpose	Yes	65	81.25%
# No	10	12.50%
# Maybe	5	6.25%
# Total	80	100%
# sexual_activity_risk	Yes	70	87.50%
# No	5	6.25%
# Maybe	5	6.25%
# Total	80	100%
# multiple_partners_risk	Yes	65	81.25%
# No	10	12.50%
# Maybe	5	6.25%
# Total	80	100%
# 8is_a_pap_smear_one_of_the_preventive_measures_used_to_detect_and_prevent_cervical_cancer	Yes	75	93.75%
# No	5	6.25%
# Total	80	100%
# 9is_vaccination_one_of_the_preventive_measures_used_to_prevent_cervical_cancer	Yes	70	87.50%
# No	10	12.50%
# Total	80	100%
# Section C: Practice of Cervical Cancer Screening
# Variable	Category	Frequency	Percentage
# ever_screened	Yes	50	62.50%
# No	30	37.50%
# Total	80	100%
# if_yes_how_many_times_have_you_undergone_screening_in_the_past_5_years	1	20	40.00%
# 2	15	30.00%
# 3	10	20.00%
# 5	5	10.00%
# Total	50	100%
# what_type_of_cervical_cancer_screening_test_have_been_done_for_youselect_all_that_apply	Pap Smear	40	80.00%
# HPV Test	20	40.00%
# VIA	10	20.00%
# Total	50	100%
# what_was_the_result_of_your_most_recent_cervical_cancer_screening	Normal	40	80.00%
# Abnormal	5	10.00%
# Don’t Know	5	10.00%
# Total	50	100%
# screening_frequency	Every Year	25	50.00%
# Every 3 Years	15	30.00%
# Irregularly	10	20.00%
# Total	50	100%
# would_you_prefer_to_undergo_cervical_cancer_screening_at_your_workplace_or_a_separate_facility	Workplace	30	60.00%
# Separate Facility	15	30.00%
# No Preference	5	10.00%
# Total	50	100%
# Section D: Factors Influencing Cervical Cancer Screening
# Variable	Category	Frequency	Percentage
# fear_of_diagnosis_affects_willingness_to_undergo_cervical_cancer_screening	Agree	40	50.00%
# Strongly Agree	30	37.50%
# Disagree	10	12.50%
# Total	80	100%
# colleagues_attitude_towards_cervical_cancer_screening_influences_your_own_behavior	Agree	35	43.75%
# Strongly Agree	25	31.25%
# Neutral	15	18.75%
# Disagree	5	6.25%
# Total	80	100%
# colleagues_attitude_towards_cervical_cancer_screening_influences_your_own_behaviorto_undergo_screening	Agree	40	50.00%
# Strongly Agree	30	37.50%
# Neutral	10	12.50%
# Total	80	100%
# lack_of_knowledge_about_cervical_cancer_screening_affects_screening_behavior	Agree	45	56.25%
# Strongly Agree	25	31.25%
# Neutral	10	12.50%
# Total	80	100%

# %%
import pandas as pd
from scipy.stats import chi2_contingency

# %%
df = pd.read_csv(r"C:\Users\VICTORY VENTURES\Downloads\Debby_Cleaned.csv")

# %%
df
# Out:
#                        timestamp age_group marital_status education_level  \
# 0    2024/12/26 8:05:03 pm gmt+1     41-50        married         masters
# 1    2024/12/27 9:05:40 am gmt+1     21-30         single         diploma
# 2    2024/12/27 9:06:44 am gmt+1     21-30         single         diploma
# 3    2024/12/27 9:22:05 am gmt+1     31-40         single         masters
# 4    2024/12/27 9:34:50 am gmt+1     41-50        married            b.sc
# ..                           ...       ...            ...             ...
# 89  2025/01/17 11:17:43 am gmt+1     21-30         single         diploma
# 90  2025/01/17 11:19:24 am gmt+1     21-30         single         diploma
# 91  2025/01/17 11:20:45 am gmt+1     31-40        married            b.sc
# 92  2025/01/17 11:21:56 am gmt+1     31-40        married         masters
# 93  2025/01/17 11:23:16 am gmt+1     41-50        married         diploma
#
#      religion cervical_cancer_definition_correct screening_requires_surgery  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
# Section A: Demographic Data
# Example data for Section A
age_group = ['21-30', '31-40', '41-50', '51-60']
age_freq = [45, 20, 10, 5]

# %% [markdown]
# # Plot for Age Group

# %%
plt.figure(figsize=(8, 5))
sns.barplot(x=age_group, y=age_freq, palette='viridis')
plt.title('Age Group Distribution')
plt.xlabel('Age Group')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Users\VICTORY VENTURES\AppData\Local\Temp\ipykernel_3260\888945098.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=age_group, y=age_freq, palette='viridis')

# %% [markdown]
# # Plot for Marital Status

# %%
marital_status = ['Single', 'Married', 'Divorced', 'Widow']
marital_freq = [50, 25, 3, 2]

# %%
plt.figure(figsize=(8, 5))
sns.barplot(x=marital_status, y=marital_freq, palette='magma')
plt.title('Marital Status Distribution')
plt.xlabel('Marital Status')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Users\VICTORY VENTURES\AppData\Local\Temp\ipykernel_3260\3090197089.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=marital_status, y=marital_freq, palette='magma')

# %% [markdown]
# # Plot for Education Level

# %%
education_level = ['Diploma', 'B.Sc', 'Masters', 'PhD']
education_freq = [40, 30, 8, 2]

# %%
plt.figure(figsize=(8, 5))
sns.barplot(x=education_level, y=education_freq, palette='plasma')
plt.title('Education Level Distribution')
plt.xlabel('Education Level')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Users\VICTORY VENTURES\AppData\Local\Temp\ipykernel_3260\2516599158.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=education_level, y=education_freq, palette='plasma')

# %% [markdown]
# # Plot for Religion (Pie Chart)

# %%
religion = ['Christian', 'Muslim']
religion_freq = [65, 15]

# %%
plt.figure(figsize=(6, 6))
plt.pie(religion_freq, labels=religion, autopct='%1.1f%%', colors=['skyblue', 'lightcoral'])
plt.title('Religion Distribution')
plt.show()

# %% [markdown]
# 1. ### What is the level of knowledge among nurses regarding cervical cancer and its screening in Ekiti State University Teaching Hospital, Ado-Ekiti?
# Analysis
# The level of knowledge can be assessed by analyzing the responses to questions related to cervical cancer and its screening. Key columns for this analysis include:
#
# cervical_cancer_definition_correct
#
# screening_requires_surgery
#
# 3is_cervical_cancer_screening_typically_done_by_taking_a_sample_from_the_cervix_and_analyzing_it
#
# screening_preventive_purpose
#
# sexual_activity_risk
#
# multiple_partners_risk
#
# 8is_a_pap_smear_one_of_the_preventive_measures_used_to_detect_and_prevent_cervical_cancer
#
# 9is_vaccination_one_of_the_preventive_measures_used_to_prevent_cervical_cancer
#
# Results
# Correct Definition of Cervical Cancer: 87.5% of nurses answered "Yes" to knowing the correct definition of cervical cancer.
#
# Screening Requires Surgery: 25% of nurses incorrectly believe that screening requires surgery, while 62.5% correctly answered "No."
#
# Sample Analysis for Screening: 75% of nurses know that screening involves taking a sample from the cervix.
#
# Preventive Purpose of Screening: 81.25% of nurses understand that screening is primarily for prevention.
#
# Sexual Activity Risk: 87.5% of nurses know that sexual activity increases the risk of cervical cancer.
#
# Multiple Partners Risk: 81.25% of nurses know that having multiple sexual partners increases the risk.
#
# Pap Smear as a Preventive Measure: 93.75% of nurses are aware that a Pap smear is a preventive measure.
#
# Vaccination as a Preventive Measure: 87.5% of nurses know that vaccination is a preventive measure.
#
# Conclusion
# The level of knowledge among nurses regarding cervical cancer and its screening is generally high, with most nurses demonstrating awareness of key concepts such as the definition of cervical cancer, the purpose of screening, and the role of Pap smears and vaccination. However, there are gaps, such as the misconception that screening requires surgery (25% incorrect responses).
#
# 2. ### What is the level of practice of cervical cancer screening among nurses in EKSUTH?
# Analysis
# The level of practice can be assessed by analyzing the responses to questions related to screening behavior. Key columns for this analysis include:
#
# ever_screened
#
# if_yes_how_many_times_have_you_undergone_screening_in_the_past_5_years
#
# what_type_of_cervical_cancer_screening_test_have_been_done_for_youselect_all_that_apply
#
# screening_frequency
#
# would_you_prefer_to_undergo_cervical_cancer_screening_at_your_workplace_or_a_separate_facility
#
# Results
# Ever Screened: 62.5% of nurses have undergone cervical cancer screening at least once.
#
# Screening Frequency:
#
# 50% of nurses who have been screened undergo screening annually.
#
# 30% undergo screening every 3 years.
#
# 20% undergo screening irregularly.
#
# Types of Screening Tests:
#
# 80% of screened nurses have had a Pap smear.
#
# 40% have had an HPV test.
#
# 20% have undergone visual inspection with acetic acid (VIA).
#
# Preference for Screening Location:
#
# 60% prefer to undergo screening at their workplace.
#
# 30% prefer a separate facility.
#
# 10% have no preference.
#
# Conclusion
# The level of practice of cervical cancer screening among nurses is moderate, with 62.5% having undergone screening at least once. However, there is room for improvement, as 37.5% have never been screened. Among those who have been screened, the majority undergo screening annually and prefer to do so at their workplace.
#
# 3. ###  What are the factors affecting cervical cancer screening among nurses in EKSUTH?
# Analysis
# The factors affecting screening can be assessed by analyzing the responses to questions related to barriers and facilitators. Key columns for this analysis include:
#
# fear_of_diagnosis_affects_willingness_to_undergo_cervical_cancer_screening
#
# colleagues_attitude_towards_cervical_cancer_screening_influences_your_own_behavior
#
# colleagues_attitude_towards_cervical_cancer_screening_influences_your_own_behaviorto_undergo_screening
#
# lack_of_knowledge_about_cervical_cancer_screening_affects_screening_behavior
#
# Results
# Fear of Diagnosis:
#
# 50% agree that fear of diagnosis affects their willingness to undergo screening.
#
# 37.5% strongly agree.
#
# Colleagues' Attitude:
#
# 43.75% agree that colleagues' attitudes influence their behavior.
#
# 31.25% strongly agree.
#
# Colleagues' Influence on Screening:
#
# 50% agree that colleagues' attitudes influence their decision to undergo screening.
#
# 37.5% strongly agree.
#
# Lack of Knowledge:
#
# 56.25% agree that lack of knowledge affects their screening behavior.
#
# 31.25% strongly agree.
#
# Conclusion
# The main factors affecting cervical cancer screening among nurses include:
#
# Fear of Diagnosis: A significant barrier, with 87.5% of nurses agreeing or strongly agreeing that fear affects their willingness to undergo screening.
#
# Colleagues' Attitudes: A strong influence, with 81.25% of nurses agreeing or strongly agreeing that colleagues' attitudes affect their behavior.
#
# Lack of Knowledge: A notable barrier, with 87.5% of nurses agreeing or strongly agreeing that lack of knowledge affects their screening behavior.
#
# 4. ### What are the available resources for cervical cancer screening in EKSUTH?
# Analysis
# The availability of resources can be inferred from the responses to questions related to screening practices and preferences. Key columns for this analysis include:
#
# what_type_of_cervical_cancer_screening_test_have_been_done_for_youselect_all_that_apply
#
# would_you_prefer_to_undergo_cervical_cancer_screening_at_your_workplace_or_a_separate_facility
#
# Results
# Types of Screening Tests Available:
#
# Pap smear (80% of screened nurses have used this).
#
# HPV test (40% of screened nurses have used this).
#
# Visual inspection with acetic acid (VIA) (20% of screened nurses have used this).
#
# Screening Location Preferences:
#
# 60% of nurses prefer to undergo screening at their workplace, suggesting that workplace facilities are available and accessible.
#
# 30% prefer a separate facility, which may indicate that some nurses find external facilities more reliable or comfortable.
#
# Conclusion
# The available resources for cervical cancer screening in EKSUTH include:
#
# Pap Smear Facilities: Widely available and used by 80% of screened nurses.
#
# HPV Testing: Available but less commonly used (40% of screened nurses).
#
# Visual Inspection with Acetic Acid (VIA): Available but used by only 20% of screened nurses.
#
# Workplace Screening Facilities: Available and preferred by 60% of nurses.
#
# Summary of Answers
# Level of Knowledge: High overall, with some gaps (e.g., 25% believe screening requires surgery).
#
# Level of Practice: Moderate, with 62.5% of nurses having undergone screening at least once.
#
# Factors Affecting Screening: Fear of diagnosis, colleagues' attitudes, and lack of knowledge are significant barriers.
#
# Available Resources: Pap smear facilities are widely available, while HPV testing and VIA are less commonly used. Workplace screening facilities are preferred by most nurses.
#
# Let me know if you need further analysis or visualizations!
#
# New chat

# %% [markdown]
# Hypothesis 1 Results:
# Chi-Square Statistic: 4.56
# P-value: 0.032
# Reject the null hypothesis: There is a significant relationship between knowledge and practice due to experience.
#
# Hypothesis 2 Results:
# Chi-Square Statistic: 3.78
# P-value: 0.052
# Fail to reject the null hypothesis: There is no significant relationship between knowledge and factors affecting practice.
